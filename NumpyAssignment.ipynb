# %% [markdown]
# # Practice Notebook: Numpy. After completeion submit it via moodle  (100 points)

# %% [markdown]
# ## 1. Import numpy, Image, PrettyTable, random libraries

# %%
import numpy as np
from PIL import Image
from prettytable import PrettyTable 
import random

# %% [markdown]
# ## 2. Open any two images from the image list using Image library and save it to image1, and image2

# %%
image1=Image.open('Pic1.jfif')
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=444x355>

# %%
image2=Image.open('Pic2.jfif')
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=442x355>

# %% [markdown]
# ## 3. Color image is a 3d Numpy array. Find out the shape of each of those images and save it array1, and array2

# %%
original_array1=np.array(image1)
original_array1.shape
# Out:
# (355, 444, 3)

# %%
original_array2=np.array(image2)
original_array2.shape
# Out:
# (355, 442, 3)

# %% [markdown]
# ## 4. If two of the image is different size, resize them. You can either resize both of them in a particular size like 400x400 or resize either of them
#
# ### use resize library from PIL
# Sample: resizedimage=image1.resize((400,400), resample=Image.NEAREST)

# %%
resized_image1=image1.resize((400,400))
resized_image1
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
resized_image2=image2.resize((400,400))
resized_image2
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %% [markdown]
# ## Find out the shape of each of those `resizedimage` and save it array1, and array2

# %%
array1=np.array(resized_image1)
array1.shape
# Out:
# (400, 400, 3)

# %%
array2=np.array(resized_image2)
array2.shape
# Out:
# (400, 400, 3)

# %% [markdown]
# ## 5.  Write down a function called "inspect" to inspect array1 and array2 Shape, length, Dimensions, and Datatype using Preetytable. Your pretty table should contain a title and look like similar to the following:
# ![image-2.png](attachment:image-2.png)

# %%
def inspect(array):
    PT=PrettyTable()
    PT.title="Numpy array Inspection"
    PT.field_names=["Shape", "len", "Dimension", "DataType"]
    PT.add_row([array.shape, len(array), array.ndim, array.dtype])
    print(PT)

# %%
inspect(array1)
# Out:
# +--------------------------------------------+
# |           Numpy array Inspection           |
# +---------------+-----+-----------+----------+
# |     Shape     | len | Dimension | DataType |
# +---------------+-----+-----------+----------+
# | (400, 400, 3) | 400 |     3     |  uint8   |
# +---------------+-----+-----------+----------+

# %%
inspect(array2)
# Out:
# +--------------------------------------------+
# |           Numpy array Inspection           |
# +---------------+-----+-----------+----------+
# |     Shape     | len | Dimension | DataType |
# +---------------+-----+-----------+----------+
# | (400, 400, 3) | 400 |     3     |  uint8   |
# +---------------+-----+-----------+----------+

# %% [markdown]
# ## 6. Perform Element wise and Array Wise comparison of array1 and array2 and add necessary comments

# %%
array1==array2
# for the entries that are False, the entry in that place in array 1 is not the same as array 2.
# for the entries that are True, the entry in that place in array 1 is equal to the entry in that place in array 2.
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]])

# %%
array1<array2
# for the entries that are False, the entry in that place in array 1 is not smaller than the entry in that place in array 2.
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
array1>array2
# for the entries that are False, the entry in that place in array 1 is not larger than the entry in that place in array 2.
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]])

# %%
array1<=array2
# for the entries that are False, the entry in that place in array 1 is not smaller than or equal to the entry in that place in array 2.
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
np.array_equal(array1,array2)
#the output is false because the arrays are not exactly the same
# Out:
# False

# %% [markdown]
# ## 7. Create a 3D random array of saze of your array1 and array2, give it name array3

# %%
from numpy import random
array3=random.randint(300, size=(400,400,3))
array3
# Out:
# array([[[ 90, 190,  84],
#         [ 36, 158,  59],
#         [116,   4,  82],
#         ...,
#         [181, 214, 207],
#         [162, 257, 175],
#         [ 84, 289, 283]],
#
#        [[274,  13, 271],
#         [158, 120, 266],
#         [123,  58, 164],
#         ...,
#         [282, 225, 214],
#         [299, 194, 113],
#         [ 60, 235, 182]],
#
#        [[116, 212, 198],
#         [187, 179, 255],
#         [ 86,  83,  50],
#         ...,
#         [229, 161,  78],
#         [196, 141, 188],
#         [ 54, 269, 258]],
#
#        ...,
#
#        [[201, 242, 149],
#         [  5,  80,  49],
#         [157,  55,  92],
#         ...,
#         [127,  10,  88],
#         [ 28,  87, 137],
#         [271, 171, 196]],
#
#        [[226,  86,  23],
#         [ 10,  67, 268],
#         [289, 152, 207],
#         ...,
#         [ 49, 274, 126],
#         [ 85, 162, 166],
#         [108,  80,   9]],
#
#        [[ 54, 105, 176],
#         [215,   1, 266],
#         [294,  85, 219],
#         ...,
#         [204, 148, 271],
#         [ 73, 259, 152],
#         [  9, 105, 293]]])

# %% [markdown]
# ## 8.Create a function called "calculation" to display `sum, min, max, mean, standard deviation, median calculations about a NumPy array using PrettyTable. Test it for array1,2,3
# ![image.png](attachment:image.png)

# %%
def calculation(array):
    PT=PrettyTable()
    PT.title="Numpy array Calculations"
    PT.field_names=['Sum',"Min",'Max','Mean','Std','Median']
    PT.add_row([array.sum(),array.min(),array.max(),array.mean(),array.std(),np.median(array)])
    print(PT)

# %%
calculation(array1)
# Out:
# +-----------------------------------------------------------------------+
# |                        Numpy array Calculations                       |
# +----------+-----+-----+-------------------+-------------------+--------+
# |   Sum    | Min | Max |        Mean       |        Std        | Median |
# +----------+-----+-----+-------------------+-------------------+--------+
# | 36258247 |  0  | 255 | 75.53801458333334 | 70.72105103191072 |  60.0  |
# +----------+-----+-----+-------------------+-------------------+--------+

# %%
calculation(array2)
# Out:
# +----------------------------------------------------------------------+
# |                       Numpy array Calculations                       |
# +----------+-----+-----+-------------------+------------------+--------+
# |   Sum    | Min | Max |        Mean       |       Std        | Median |
# +----------+-----+-----+-------------------+------------------+--------+
# | 40209194 |  0  | 255 | 83.76915416666667 | 69.9575777539591 |  61.0  |
# +----------+-----+-----+-------------------+------------------+--------+

# %%
calculation(array3)
# Out:
# +------------------------------------------------------------------------+
# |                        Numpy array Calculations                        |
# +----------+-----+-----+--------------------+-------------------+--------+
# |   Sum    | Min | Max |        Mean        |        Std        | Median |
# +----------+-----+-----+--------------------+-------------------+--------+
# | 71829829 |  0  | 299 | 149.64547708333333 | 86.60243827736547 | 150.0  |
# +----------+-----+-----+--------------------+-------------------+--------+

# %% [markdown]
# ## 9.Create a function called "arithmatic" to display `Subtraction (np.subtract(a,b)), Addition,  Multiplication calculations about two NumPy array using PrettyTable. Test it for
# * array1, array3
# * array2, array3
# * array1, array2
# ![image.png](attachment:image.png)

# %%
def arithmetic(a,b):
    PT=PrettyTable()
    PT.title='Numpy array Arithmetic Operation'
    PT.field_names=['Subtraction',"Addition",'Multiplication']
    PT.add_row([np.subtract(a,b),np.add(a,b),np.multiply(a,b)])
    print(PT)

# %%
arithmetic(array1,array3)
# Out:
# +--------------------------------------------------------------------+
# |                  Numpy array Arithmetic Operation                  |
# +----------------------+-------------------+-------------------------+
# |     Subtraction      |      Addition     |      Multiplication     |
# +----------------------+-------------------+-------------------------+
# |  [[[ -39 -117   12]  |  [[[141 263 180]  |  [[[ 4590 13870  8064]  |
# |    [  18  -82   40]  |    [ 90 234 158]  |    [ 1944 12008  5841]  |
# |    [ -81   53   -2]  |    [151  61 162]  |    [ 4060   228  6560]  |
# |          ...         |         ...       |            ...          |
# |    [-178 -213 -205]  |    [184 215 209]  |    [  543   214   414]  |
# |    [-159 -256 -173]  |    [165 258 177]  |    [  486   257   350]  |
# |   [ -81 -288 -281]]  |    [ 87 290 285]] |    [  252   289   566]] |
# |                      |                   |                         |
# |   [[-228   55 -180]  |   [[320  81 362]  |   [[12604   884 24661]  |
# |    [-108  -49 -172]  |    [208 191 360]  |    [ 7900  8520 25004]  |
# |    [ -88   -1  -84]  |    [158 115 244]  |    [ 4305  3306 13120]  |
# |          ...         |         ...       |            ...          |
# |    [-280 -225 -213]  |    [284 225 215]  |    [  564     0   214]  |
# |    [-297 -194 -112]  |    [301 194 114]  |    [  598     0   113]  |
# |   [ -58 -235 -181]]  |    [ 62 235 183]] |    [  120     0   182]] |
# |                      |                   |                         |
# |   [[ -75 -147 -111]  |   [[157 277 285]  |   [[ 4756 13780 17226]  |
# |    [-148 -116 -170]  |    [226 242 340]  |    [ 7293 11277 21675]  |
# |    [ -49  -22   33]  |    [123 144 133]  |    [ 3182  5063  4150]  |
# |          ...         |         ...       |            ...          |
# |    [-229 -161  -78]  |    [229 161  78]  |    [    0     0     0]  |
# |    [-196 -141 -188]  |    [196 141 188]  |    [    0     0     0]  |
# |   [ -54 -269 -258]]  |    [ 54 269 258]] |    [    0     0     0]] |
# |                      |                   |                         |
# |          ...         |         ...       |            ...          |
# |                      |                   |                         |
# |   [[-201 -242 -149]  |   [[201 242 149]  |   [[    0     0     0]  |
# |    [  -5  -80  -49]  |    [  5  80  49]  |    [    0     0     0]  |
# |    [-157  -55  -92]  |    [157  55  92]  |    [    0     0     0]  |
# |          ...         |         ...       |            ...          |
# |    [-127  -10  -88]  |    [127  10  88]  |    [    0     0     0]  |
# |    [ -27  -86 -136]  |    [ 29  88 138]  |    [   28    87   137]  |
# |   [-252 -152 -177]]  |    [290 190 215]] |    [ 5149  3249  3724]] |
# |                      |                   |                         |
# |   [[-226  -86  -23]  |   [[226  86  23]  |   [[    0     0     0]  |
# |    [ -10  -67 -268]  |    [ 10  67 268]  |    [    0     0     0]  |
# |    [-289 -152 -207]  |    [289 152 207]  |    [    0     0     0]  |
# |          ...         |         ...       |            ...          |
# |    [ -49 -274 -126]  |    [ 49 274 126]  |    [    0     0     0]  |
# |    [ -80 -157 -161]  |    [ 90 167 171]  |    [  425   810   830]  |
# |   [ -59  -31   40]]  |    [157 129  58]] |    [ 5292  3920   441]] |
# |                      |                   |                         |
# |   [[ -54 -105 -176]  |   [[ 54 105 176]  |   [[    0     0     0]  |
# |    [-215   -1 -266]  |    [215   1 266]  |    [    0     0     0]  |
# |    [-294  -85 -219]  |    [294  85 219]  |    [    0     0     0]  |
# |          ...         |         ...       |            ...          |
# |    [-204 -148 -271]  |    [204 148 271]  |    [    0     0     0]  |
# |    [ -69 -255 -148]  |    [ 77 263 156]  |    [  292  1036   608]  |
# |   [  48  -48 -236]]] |   [ 66 162 350]]] |   [  513  5985 16701]]] |
# +----------------------+-------------------+-------------------------+

# %%
arithmetic(array2,array3)
# Out:
# +--------------------------------------------------------------------+
# |                  Numpy array Arithmetic Operation                  |
# +----------------------+-------------------+-------------------------+
# |     Subtraction      |      Addition     |      Multiplication     |
# +----------------------+-------------------+-------------------------+
# |  [[[ -90 -177  -46]  |  [[[ 90 203 122]  |  [[[    0  2470  3192]  |
# |    [ -36 -144  -20]  |    [ 36 172  98]  |    [    0  2212  2301]  |
# |    [-116   11  -42]  |    [116  19 122]  |    [    0    60  3280]  |
# |          ...         |         ...       |            ...          |
# |    [-165 -180 -153]  |    [197 248 261]  |    [ 2896  7276 11178]  |
# |    [-144 -221 -116]  |    [180 293 234]  |    [ 2916  9252 10325]  |
# |   [ -66 -253 -223]]  |    [102 325 343]] |    [ 1512 10404 16980]] |
# |                      |                   |                         |
# |   [[-274    2 -231]  |   [[274  28 311]  |   [[    0   195 10840]  |
# |    [-158 -105 -226]  |    [158 135 306]  |    [    0  1800 10640]  |
# |    [-123  -42 -123]  |    [123  74 205]  |    [    0   928  6724]  |
# |          ...         |         ...       |            ...          |
# |    [-266 -191 -159]  |    [298 259 269]  |    [ 4512  7650 11770]  |
# |    [-281 -158  -54]  |    [317 230 172]  |    [ 5382  6984  6667]  |
# |   [ -42 -199 -122]]  |    [ 78 271 242]] |    [ 1080  8460 10920]] |
# |                      |                   |                         |
# |   [[-115 -196 -157]  |   [[117 228 239]  |   [[  116  3392  8118]  |
# |    [-186 -163 -214]  |    [188 195 296]  |    [  187  2864 10455]  |
# |    [ -85  -66   -8]  |    [ 87 100  92]  |    [   86  1411  2100]  |
# |          ...         |         ...       |            ...          |
# |    [-213 -127  -23]  |    [245 195 133]  |    [ 3664  5474  4290]  |
# |    [-178 -105 -129]  |    [214 177 247]  |    [ 3528  5076 11092]  |
# |   [ -36 -233 -198]]  |    [ 72 305 318]] |    [  972  9684 15480]] |
# |                      |                   |                         |
# |          ...         |         ...       |            ...          |
# |                      |                   |                         |
# |   [[-155 -145   -5]  |   [[247 339 293]  |   [[ 9246 23474 21456]  |
# |    [  44   20   98]  |    [ 54 180 196]  |    [  245  8000  7203]  |
# |    [-107   47   57]  |    [207 157 241]  |    [ 7850  5610 13708]  |
# |          ...         |         ...       |            ...          |
# |    [  -1  165  122]  |    [253 185 298]  |    [16002  1750 18480]  |
# |    [ 105   95   82]  |    [161 269 356]  |    [ 3724 15834 30003]  |
# |   [-141   10   21]]  |    [401 352 413]] |    [35230 30951 42532]] |
# |                      |                   |                         |
# |   [[-181   11  121]  |   [[271 183 167]  |   [[10170  8342  3312]  |
# |    [  36   31 -123]  |    [ 56 165 413]  |    [  460  6566 38860]  |
# |    [-242  -53  -61]  |    [336 251 353]  |    [13583 15048 30222]  |
# |          ...         |         ...       |            ...          |
# |    [  80  -96   90]  |    [178 452 342]  |    [ 6321 48772 27216]  |
# |    [  42   18   53]  |    [212 342 385]  |    [10795 29160 36354]  |
# |   [  16   96  207]]  |    [232 256 225]] |    [13392 14080  1944]] |
# |                      |                   |                         |
# |   [[  -7   -6  -30]  |   [[101 204 322]  |   [[ 2538 10395 25696]  |
# |    [-169   97 -121]  |    [261  99 411]  |    [ 9890    98 38570]  |
# |    [-249   12  -75]  |    [339 182 363]  |    [13230  8245 31536]  |
# |          ...         |         ...       |            ...          |
# |    [ -73   32  -53]  |    [335 328 489]  |    [26724 26640 59078]  |
# |    [  54  -80   65]  |    [200 438 369]  |    [ 9271 46361 32984]  |
# |   [ 113   69  -80]]] |   [131 279 506]]] |   [ 1098 18270 62409]]] |
# +----------------------+-------------------+-------------------------+

# %%
arithmetic(array1,array2)
# Out:
# +-----------------------------------------------------------+
# |              Numpy array Arithmetic Operation             |
# +-------------------+-------------------+-------------------+
# |    Subtraction    |      Addition     |   Multiplication  |
# +-------------------+-------------------+-------------------+
# |  [[[ 51  60  58]  |  [[[ 51  86 134]  |  [[[  0 181  64]  |
# |    [ 54  62  60]  |    [ 54  90 138]  |    [  0  40  21]  |
# |    [ 35  42  40]  |    [ 35  72 120]  |    [  0  87 128]  |
# |         ...       |         ...       |         ...       |
# |    [243 223 204]  |    [ 19  35  56]  |    [ 48  34 108]  |
# |    [241 221 199]  |    [ 21  37  61]  |    [ 54  36 118]  |
# |    [241 221 198]] |    [ 21  37  62]] |    [ 54  36 120]] |
# |                   |                   |                   |
# |   [[ 46  53  51]  |   [[ 46  83 131]  |   [[  0 252  56]  |
# |    [ 50  56  54]  |    [ 50  86 134]  |    [  0  41 176]  |
# |    [ 35  41  39]  |    [ 35  73 121]  |    [  0 144 208]  |
# |         ...       |         ...       |         ...       |
# |    [242 222 202]  |    [ 18  34  56]  |    [ 32   0  55]  |
# |    [240 220 198]  |    [ 20  36  60]  |    [ 36   0  59]  |
# |    [240 220 197]] |    [ 20  36  61]] |    [ 36   0  60]] |
# |                   |                   |                   |
# |   [[ 40  49  46]  |   [[ 42  81 128]  |   [[ 41  16 239]  |
# |    [ 38  47  44]  |    [ 40  79 126]  |    [ 39 240 157]  |
# |    [ 36  44  41]  |    [ 38  78 125]  |    [ 37  13 158]  |
# |         ...       |         ...       |         ...       |
# |    [240 222 201]  |    [ 16  34  55]  |    [  0   0   0]  |
# |    [238 220 197]  |    [ 18  36  59]  |    [  0   0   0]  |
# |    [238 220 196]] |    [ 18  36  60]] |    [  0   0   0]] |
# |                   |                   |                   |
# |         ...       |         ...       |         ...       |
# |                   |                   |                   |
# |   [[210 159 112]  |   [[ 46  97 144]  |   [[  0   0   0]  |
# |    [207 156 109]  |    [ 49 100 147]  |    [  0   0   0]  |
# |    [206 154 107]  |    [ 50 102 149]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [130  81  46]  |    [126 175 210]  |    [  0   0   0]  |
# |    [124  75  38]  |    [134 183 220]  |    [133 182 219]  |
# |    [145  94  58]] |    [149 200 236]] |    [166 111  27]] |
# |                   |                   |                   |
# |   [[211 159 112]  |   [[ 45  97 144]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [209 157 110]  |    [ 47  99 146]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [127  78  40]  |    [129 178 216]  |    [  0   0   0]  |
# |    [134  81  42]  |    [132 185 224]  |    [123 132  71]  |
# |    [181 129  89]] |    [173 225   9]] |    [188 176  88]] |
# |                   |                   |                   |
# |   [[209 157 110]  |   [[ 47  99 146]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [211 159 112]  |    [ 45  97 144]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [125  76  38]  |    [131 180 218]  |    [  0   0   0]  |
# |    [133  81  43]  |    [131 183 221]  |    [252 204 100]  |
# |   [191 139 100]]] |   [179 231  14]]] |   [ 42 190 109]]] |
# +-------------------+-------------------+-------------------+

# %% [markdown]
# ## 10. What is the difference between reshape and resize? Reshape and resize 3D array2 to a 2D array. Make sure keep in mind the original shape.

# %%
# reshape() does not changes the original array but only returns the changed array, 
# whereas the resize() method returns nothing and directly changes the original array.

# array2.shape is originally (400,400,3)
array2.reshape(300,800,2)
# Out:
# array([[[  0,  13],
#         [ 38,   0],
#         [ 14,  39],
#         ...,
#         [ 11,  31],
#         [  2,  10],
#         [ 29,   2]],
#
#        [[ 10,  29],
#         [  2,  10],
#         [ 29,   2],
#         ...,
#         [ 20,   1],
#         [  9,  20],
#         [  1,   9]],
#
#        [[ 22,   1],
#         [  9,  22],
#         [  0,   8],
#         ...,
#         [ 18,  35],
#         [ 59,  18],
#         [ 35,  59]],
#
#        ...,
#
#        [[ 36,  85],
#         [132,  39],
#         [ 89, 135],
#         ...,
#         [115, 159],
#         [ 87, 127],
#         [172,  92]],
#
#        [[132, 176],
#         [ 89, 130],
#         [174,  91],
#         ...,
#         [186, 140],
#         [166, 191],
#         [148, 174]],
#
#        [[199, 146],
#         [172, 197],
#         [138, 165],
#         ...,
#         [127, 179],
#         [217, 122],
#         [174, 213]]], dtype=uint8)

# %%
array2.shape
# Out:
# (400, 400, 3)

# %%
array2.resize(30,8000,2)
array2.shape
# Out:
# (30, 8000, 2)

# %% [markdown]
# ## 11. Vertically stack array1 and array3 and create new array4

# %%
array4=np.vstack((array1,array3))
array4
# Out:
# array([[[ 51,  73,  96],
#         [ 54,  76,  99],
#         [ 35,  57,  80],
#         ...,
#         [  3,   1,   2],
#         [  3,   1,   2],
#         [  3,   1,   2]],
#
#        [[ 46,  68,  91],
#         [ 50,  71,  94],
#         [ 35,  57,  80],
#         ...,
#         [  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1]],
#
#        [[ 41,  65,  87],
#         [ 39,  63,  85],
#         [ 37,  61,  83],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#
#        [[201, 242, 149],
#         [  5,  80,  49],
#         [157,  55,  92],
#         ...,
#         [127,  10,  88],
#         [ 28,  87, 137],
#         [271, 171, 196]],
#
#        [[226,  86,  23],
#         [ 10,  67, 268],
#         [289, 152, 207],
#         ...,
#         [ 49, 274, 126],
#         [ 85, 162, 166],
#         [108,  80,   9]],
#
#        [[ 54, 105, 176],
#         [215,   1, 266],
#         [294,  85, 219],
#         ...,
#         [204, 148, 271],
#         [ 73, 259, 152],
#         [  9, 105, 293]]])

# %% [markdown]
# ## 12. Save array4 at your system and load it back

# %%
np.save('array.npy',array4)

# %%
np.load('array.npy')
# Out:
# array([[[ 51,  73,  96],
#         [ 54,  76,  99],
#         [ 35,  57,  80],
#         ...,
#         [  3,   1,   2],
#         [  3,   1,   2],
#         [  3,   1,   2]],
#
#        [[ 46,  68,  91],
#         [ 50,  71,  94],
#         [ 35,  57,  80],
#         ...,
#         [  2,   0,   1],
#         [  2,   0,   1],
#         [  2,   0,   1]],
#
#        [[ 41,  65,  87],
#         [ 39,  63,  85],
#         [ 37,  61,  83],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#
#        [[201, 242, 149],
#         [  5,  80,  49],
#         [157,  55,  92],
#         ...,
#         [127,  10,  88],
#         [ 28,  87, 137],
#         [271, 171, 196]],
#
#        [[226,  86,  23],
#         [ 10,  67, 268],
#         [289, 152, 207],
#         ...,
#         [ 49, 274, 126],
#         [ 85, 162, 166],
#         [108,  80,   9]],
#
#        [[ 54, 105, 176],
#         [215,   1, 266],
#         [294,  85, 219],
#         ...,
#         [204, 148, 271],
#         [ 73, 259, 152],
#         [  9, 105, 293]]])
